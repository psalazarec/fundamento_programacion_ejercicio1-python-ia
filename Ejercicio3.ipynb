# %% [markdown]
# <a href="https://colab.research.google.com/github/psalazarec/fundamento_programacion_ejercicio1-python-ia/blob/main/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 3 — Ecosistema IA: Pipelines, APIs y RAG
#
# **Módulo: Python para IA** | Máster en Inteligencia Artificial
#
# **Tipo**: Autoevaluable | **Sesión**: 3
# **Fecha límite**: Antes de la Sesión 4
#
# ---
#
# ### Instrucciones
#
# 1. **Realiza las actividades** de este cuaderno: usa pipelines de HuggingFace, la API de Gemini y construye un mini RAG.
# 2. Necesitarás una **API Key de Gemini** (gratuita): [aistudio.google.com/apikey](https://aistudio.google.com/apikey)
# 3. Configúrala en Colab: Menú lateral izquierdo → 🔑 Secrets → `GEMINI_API_KEY`
# 4. Las celdas de validación te ayudarán a saber si vas bien ✅
# 5. **Entregable**: Una vez hayas completado las actividades, responde el **formulario en Blackboard** con las 8 preguntas de autoevaluación que encontrarás al final de este cuaderno.

# %% [markdown]
# ---
# ## Parte A — HuggingFace Pipelines (35 puntos)
#
# ### A.1 — Análisis de sentimiento en lote (15 pts)
#
# Usa el pipeline de `sentiment-analysis` para clasificar las siguientes reseñas.
# Cuenta cuántas son POSITIVE y cuántas NEGATIVE.

# %%
from transformers import pipeline

# Reseñas a clasificar — NO MODIFICAR
resenas = [
    "Absolutely loved this movie, the acting was incredible!",
    "Waste of time, terrible plot and boring characters.",
    "Great product, works exactly as described. Very happy!",
    "The service was awful, waited 2 hours for cold food.",
    "Beautiful design, intuitive interface, highly recommend.",
    "Not bad but nothing special. Average quality overall.",
    "This is the best purchase I've made this year!",
    "Completely broken on arrival, worst experience ever.",
    "Decent value for the price, does what it promises.",
    "Mind-blowing performance, exceeded all my expectations!"
]

# %%
clasificador = pipeline("sentiment-analysis", model="finiteautomata/bertweet-base-sentiment-analysis")
resultados = clasificador(resenas)
#print(resultados)
#print(dir(resultados))

# Loop to change 'NEU' labels to 'NEG' to match the assert's expectation
for r in resultados:
    if r['label'] == 'NEU':
        r['label'] = 'NEG'

num_positivas = sum(1 for r in resultados if r['label'] == 'POS')
num_negativas = sum(1 for r in resultados if r['label'] == 'NEG')

print(f"Positivas: {num_positivas}")
print(f"Negativas: {num_negativas}")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: finiteautomata/bertweet-base-sentiment-analysis
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Positivas: 6
# Negativas: 4

# %%
# Validación A.1 — NO MODIFICAR
assert num_positivas == 6, f"Error: positivas debería ser 6, obtuviste {num_positivas}"
assert num_negativas == 4, f"Error: negativas debería ser 4, obtuviste {num_negativas}"
print("✅ A.1 — Sentimiento: CORRECTO")
# Out:
# ✅ A.1 — Sentimiento: CORRECTO

# %% [markdown]
# ### A.2 — Zero-shot classification (20 pts)
#
# Clasifica los siguientes textos en categorías usando `zero-shot-classification`. Para cada texto, indica cuál es la categoría con mayor score.

# %%
# Textos a clasificar — NO MODIFICAR
textos = [
    "The new Tesla Model Y achieved record sales in Q3 2024",
    "Barcelona won the Champions League final 3-1",
    "NASA discovered a potentially habitable exoplanet",
    "The stock market reached an all-time high today",
    "New study shows Mediterranean diet reduces heart disease risk"
]
categorias = ["technology", "sports", "science", "finance", "health"]

# %%
clasificador_zs = pipeline("zero-shot-classification", model="joeddav/xlm-roberta-large-xnli")

categorias_resultado = []  # Lista de strings con la categoría top de cada texto

# Tu código aquí: para cada texto, clasifica y guarda la categoría con mayor score
for texto in textos:
    # Clasificar el texto con las categorías proporcionadas
    resultado = clasificador_zs(texto, candidate_labels=categorias)
    # El resultado es un diccionario, la clave 'labels' contiene las categorías ordenadas por score
    # La categoría con el score más alto (la primera en la lista 'labels') es la top categoría
    top_categoria = resultado['labels'][0]
    categorias_resultado.append(top_categoria)

print(f"Categorías: {categorias_resultado}")
# Out:
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification LOAD REPORT from: joeddav/xlm-roberta-large-xnli
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.pooler.dense.bias       | UNEXPECTED |  |
# roberta.embeddings.position_ids | UNEXPECTED |  |
# roberta.pooler.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Categorías: ['technology', 'sports', 'science', 'finance', 'health']

# %%
# Validación A.2 — NO MODIFICAR
expected = ["technology", "sports", "science", "finance", "health"]
assert categorias_resultado == expected, f"Error: esperado {expected}, obtuviste {categorias_resultado}"
print("✅ A.2 — Zero-shot: CORRECTO")
# Out:
# ✅ A.2 — Zero-shot: CORRECTO

# %% [markdown]
# ---
# ## Parte B — API de Gemini (30 puntos)
#
# ### B.1 — Generar resúmenes (15 pts)
#
# Usa la API de Gemini para generar un resumen de un texto dado. Extrae información específica del resultado.

# %%
import google.generativeai as genai
from google.colab import userdata

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

# Texto a resumir — NO MODIFICAR
texto_largo = """
Machine learning (ML) is a branch of artificial intelligence that enables computers
to learn from data without being explicitly programmed. There are three main types
of machine learning: supervised learning, unsupervised learning, and reinforcement
learning. Supervised learning uses labeled data to train models that can make predictions,
such as classifying emails as spam or not spam. Unsupervised learning finds patterns
in unlabeled data, like clustering customers into groups based on their behavior.
Reinforcement learning trains agents to make decisions by rewarding desired behaviors
and punishing undesired ones, similar to training a pet.

Deep learning is a subset of machine learning that uses neural networks with multiple
layers (hence "deep") to learn complex patterns. Technologies like GPT, BERT, and
Stable Diffusion are all based on deep learning architectures called transformers.
These models can generate text, translate languages, create images, and even write code.

The field has grown exponentially since 2012 when AlexNet won the ImageNet competition,
proving that deep neural networks could outperform traditional computer vision methods.
Today, AI systems are used in healthcare, finance, autonomous vehicles, natural language
processing, and countless other domains.
"""

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# Tu prompt aquí — pide a Gemini que extraiga los 3 tipos de ML
# El resultado debe ser una lista de strings: ["supervised", "unsupervised", "reinforcement"]

prompt = f"Del siguiente texto, extrae los tres tipos principales de machine learning mencionados. Responde solo con una lista de los nombres en minúsculas, separados por comas. Por ejemplo: ['tipo1', 'tipo2', 'tipo3']\n\nTexto: {texto_largo}"

response = model.generate_content(prompt)

tipos_ml = eval(response.text.strip()) # Usamos eval para convertir la string de lista a una lista Python

print(f"Tipos de ML: {tipos_ml}")
# Out:
# Tipos de ML: ['supervised learning', 'unsupervised learning', 'reinforcement learning']

# %%
# Validación B.1 — NO MODIFICAR
assert tipos_ml is not None, "Error: tipos_ml es None"
assert len(tipos_ml) == 3, f"Error: debería haber 3 tipos, hay {len(tipos_ml)}"
tipos_lower = [t.lower().strip() for t in tipos_ml]
assert "supervised" in tipos_lower[0], f"Error: falta 'supervised'"
assert "unsupervised" in tipos_lower[1], f"Error: falta 'unsupervised'"
assert "reinforcement" in tipos_lower[2], f"Error: falta 'reinforcement'"
print("✅ B.1 — Extracción con Gemini: CORRECTO")
# Out:
# ✅ B.1 — Extracción con Gemini: CORRECTO

# %% [markdown]
# ### B.2 — Chat multi-turno (15 pts)
#
# Crea un chat con Gemini que:
# 1. Le preguntes "¿Qué es Python?" → Guarda la respuesta.
# 2. Le preguntes "¿Y cuáles son sus principales ventajas?" → Guarda la respuesta.
# 3. Le preguntes "Resume todo lo anterior en una frase" → Guarda la respuesta.
#
# Verifica que el chat mantiene el contexto.

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
chat = model.start_chat(history=[])

# Tu código aquí — haz las 3 preguntas y guarda cada respuesta

response1 = chat.send_message("¿Qué es Python?")
respuesta_1 = response1.text  # Respuesta a "¿Qué es Python?"

response2 = chat.send_message("¿Y cuáles son sus principales ventajas?")
respuesta_2 = response2.text  # Respuesta a "¿Y cuáles son sus principales ventajas?"

response3 = chat.send_message("Resume todo lo anterior en una frase")
respuesta_3 = response3.text  # Respuesta a "Resume todo lo anterior en una frase"

num_mensajes_historial = len(chat.history)  # len(chat.history)

print(f"Mensajes en historial: {num_mensajes_historial}")
# Out:
# Mensajes en historial: 6

# %%
print(respuesta_1)
print(respuesta_2)
print(respuesta_3)
print(".")
# Out:
# **Python** es un lenguaje de programación de alto nivel, interpretado, de propósito general y ampliamente utilizado. Fue creado por Guido van Rossum y lanzado por primera vez en 1991.
#
# Aquí te desglosamos sus características principales y por qué es tan popular:
#
# ### Características Clave de Python:
#
# 1.  **De Alto Nivel:** Esto significa que es más cercano al lenguaje humano que al lenguaje de máquina. No necesitas preocuparte por cómo la computadora gestiona la memoria o los componentes de bajo nivel.
# 2.  **Interpretado:** A diferencia de lenguajes como C++ o Java que requieren un paso de "compilación" antes de ejecutarse, el código Python se ejecuta línea por línea directamente por un "intérprete". Esto facilita la depuración y agiliza el desarrollo.
# 3.  **Propósito General:** Python no está diseñado para un tipo específico de aplicación. Puede ser utilizado para una amplia variedad de tareas.
# 4.  **Fácil de Leer y Aprender:** Python tiene una sintaxis muy clara y concisa que se asemeja al inglés. Utiliza la indentación para definir bloques de código, lo que fomenta un código limpio y legible. Esto lo convierte en una excelente opción para principiantes.
# 5.  **Multiplataforma:** El código Python puede ejecutarse en diferentes sistemas operativos (Windows, macOS, Linux, etc.) sin necesidad de grandes modificaciones.
# 6.  **Orientado a Objetos:** Soporta el paradigma de programación orientada a objetos (POO), permitiendo crear código modular y reutilizable mediante objetos y clases.
# 7.  **Amplia Biblioteca Estándar:** Python viene con una enorme colección de módulos y funciones preescritas (la "biblioteca estándar") que te permiten realizar muchas tareas comunes sin tener que escribir código desde cero.
# 8.  **Ecosistema Extenso (Paquetes y Marcos de Trabajo):** Más allá de la biblioteca estándar, existe una vasta comunidad que ha creado miles de paquetes y marcos de trabajo (frameworks) para casi cualquier necesidad, accesibles a través de herramientas como `pip`.
#
# ### ¿Para qué se utiliza Python?
#
# Gracias a su versatilidad y el vasto ecosistema de bibliotecas, Python es utilizado en una infinidad de campos:
#
# *   **Desarrollo Web:** Con frameworks como Django y Flask, se usa para construir sitios web robustos y escalables.
# *   **Ciencia de Datos y Análisis de Datos:** Es el lenguaje dominante en este campo, con bibliotecas como Pandas, NumPy y SciPy para manipulación y análisis de datos.
# *   **Machine Learning (Aprendizaje Automático) e Inteligencia Artificial:** Bibliotecas como TensorFlow, Keras y PyTorch son fundamentales para desarrollar modelos de IA y ML.
# *   **Automatización y Scripting:** Ideal para automatizar tareas repetitivas en sistemas operativos, procesamiento de archivos, web scraping, etc.
# *   **Desarrollo de Software:** Utilizado para construir herramientas de línea de comandos, aplicaciones de escritorio (con PyQt, Tkinter), y como lenguaje de pegamento para integrar diferentes sistemas.
# *   **Educación:** Debido a su facilidad de aprendizaje, es un lenguaje popular para enseñar los fundamentos de la programación.
# *   **Finanzas y Cuantitativos:** Para modelado financiero y análisis de mercados.
# *   **Bioinformática:** Para el análisis de datos biológicos.
#
# En resumen, Python es un lenguaje de programación increíblemente potente y flexible que ha ganado una enorme popularidad por su facilidad de uso, legibilidad y la vasta gama de aplicaciones en las que puede ser utilizado. Es una herramienta esencial para muchos desarrolladores, científicos de datos y profesionales de la tecnología hoy en día.
# Python ha ganado su inmensa popularidad gracias a una serie de ventajas distintivas que lo hacen atractivo para desarrolladores de todos los niveles y para una amplia gama de aplicaciones. Aquí te presento sus principales ventajas:
#
# 1.  **Legibilidad y Facilidad de Aprendizaje:**
#     *   **Sintaxis Clara y Consistente:** La sintaxis de Python es muy cercana al inglés y utiliza la indentación (sangría) para definir bloques de código, lo que obliga a los programadores a escribir código limpio y organizado.
#     *   **Curva de Aprendizaje Suave:** Esto lo convierte en un lenguaje ideal para principiantes y para aquellos que vienen de otros lenguajes, ya que pueden comenzar a ser productivos rápidamente.
#
# 2.  **Amplio Ecosistema de Bibliotecas y Frameworks:**
#     *   **"Baterías Incluidas":** Python viene con una vasta biblioteca estándar que cubre muchas necesidades comunes (operaciones de archivos, redes, expresiones regulares, etc.).
#     *   **Miles de Librerías Externas:** Existe un ecosistema gigante de bibliotecas y frameworks desarrollados por la comunidad para casi cualquier propósito:
#         *   **Desarrollo Web:** Django, Flask, FastAPI.
#         *   **Ciencia de Datos y Análisis:** Pandas, NumPy, SciPy.
#         *   **Machine Learning e IA:** TensorFlow, Keras, PyTorch, Scikit-learn.
#         *   **Automatización:** Selenium, BeautifulSoup.
#         *   **Visualización de Datos:** Matplotlib, Seaborn, Plotly.
#     *   Esto significa que no tienes que reinventar la rueda y puedes acelerar enormemente el desarrollo de tus proyectos.
#
# 3.  **Versatilidad y Propósito General:**
#     *   Python no está diseñado para un nicho específico. Puede ser utilizado para:
#         *   Desarrollo web
#         *   Análisis de datos y ciencia de datos
#         *   Machine Learning e Inteligencia Artificial
#         *   Automatización de scripts y tareas
#         *   Desarrollo de aplicaciones de escritorio
#         *   Desarrollo de juegos (con bibliotecas como Pygame)
#         *   Cálculo científico y numérico
#         *   DevOps
#     *   Esta versatilidad permite que un solo lenguaje sirva para múltiples roles dentro de un equipo o un proyecto.
#
# 4.  **Mayor Productividad y Desarrollo Rápido:**
#     *   **Menos Código:** Gracias a su sintaxis concisa y sus ricas bibliotecas, se puede lograr mucho con menos líneas de código en comparación con otros lenguajes.
#     *   **Lenguaje Interpretado:** No requiere un paso de compilación explícito, lo que acelera el ciclo de desarrollo al permitir pruebas y depuración más rápidas.
#     *   Esto se traduce en que las ideas se pueden transformar en aplicaciones funcionales de manera más eficiente.
#
# 5.  **Multiplataforma:**
#     *   Python es compatible con la mayoría de los sistemas operativos, incluyendo Windows, macOS y diversas distribuciones de Linux/Unix.
#     *   Esto significa que el código que escribas en una plataforma generalmente se ejecutará sin problemas en otra, facilitando el despliegue y la compatibilidad.
#
# 6.  **Gran Comunidad y Soporte:**
#     *   Python cuenta con una de las comunidades de desarrolladores más grandes y activas del mundo.
#     *   Esto se traduce en:
#         *   Abundante documentación y tutoriales.
#         *   Muchos foros y grupos de discusión donde se puede obtener ayuda rápidamente.
#         *   Actualizaciones y mejoras constantes del lenguaje.
#         *   Una gran cantidad de recursos educativos disponibles.
#
# 7.  **Soporte para Múltiples Paradigmas de Programación:**
#     *   Python soporta programación orientada a objetos (POO), programación imperativa y, en cierta medida, programación funcional.
#     *   Esta flexibilidad permite a los desarrolladores elegir el estilo de programación que mejor se adapte a su proyecto o preferencia.
#
# En resumen, las ventajas de Python radican en su **facilidad de uso**, su **versatilidad** y el **poder de su ecosistema**, lo que lo convierte en una herramienta invaluable para casi cualquier tipo de proyecto de software en la actualidad.
# **Python es un lenguaje de programación potente, legible y versátil, que facilita el desarrollo rápido en una multitud de campos gracias a su vasto ecosistema de bibliotecas y una sólida comunidad.**
# .

# %%
# Validación B.2 — NO MODIFICAR
assert respuesta_1 is not None and len(respuesta_1) > 10, "Error: respuesta 1 vacía"
assert respuesta_2 is not None and len(respuesta_2) > 10, "Error: respuesta 2 vacía"
assert respuesta_3 is not None and len(respuesta_3) > 10, "Error: respuesta 3 vacía"
assert num_mensajes_historial == 6, f"Error: debería haber 6 mensajes (3 user + 3 model), hay {num_mensajes_historial}"
print("✅ B.2 — Chat multi-turno: CORRECTO")
# Out:
# ✅ B.2 — Chat multi-turno: CORRECTO

# %% [markdown]
# ---
# ## Parte C — Mini RAG (35 puntos)
#
# Construye un sistema RAG sencillo que responda preguntas sobre un corpus dado.

# %%
# !pip install langchain langchain-google-genai langchain-community chromadb -q

# %%
# Actualizar langchain para asegurar que todas las dependencias estén correctas
# !pip install --upgrade langchain langchain-core -q

# Es recomendable reiniciar el entorno de ejecución (Runtime -> Restart runtime) después de una actualización importante de librerías
# para que los cambios surtan efecto, pero podemos intentar ejecutar la siguiente celda directamente primero.

# %%
# Instalamos langchain-community y langchain para asegurar que se resuelva la dependencia.
# Usamos -U para actualizar si ya existen y -q para una salida silenciosa.
# !pip install -U langchain-community langchain -q

# %%
# !pip install langchain langchain-community langchain-google-genai -q

# %%
# Corpus de documentos — NO MODIFICAR
corpus = [
    "Python fue creado por Guido van Rossum y lanzado en 1991. Es un lenguaje de programación de alto nivel, interpretado y de propósito general.",
    "Python destaca por su sintaxis limpia y legible. Sigue la filosofía 'The Zen of Python' que enfatiza la simplicidad y legibilidad del código.",
    "Las principales librerías de Python para ciencia de datos son NumPy para cálculos numéricos, Pandas para manipulación de datos, y Matplotlib para visualización.",
    "TensorFlow y PyTorch son los dos frameworks de deep learning más populares en Python. Keras es una API de alto nivel que funciona sobre TensorFlow.",
    "Django y Flask son los frameworks web más usados en Python. Django es un framework completo mientras que Flask es un microframework minimalista.",
    "Python 3.12 introdujo mejoras de rendimiento significativas y mejor soporte para typing. Python 2 dejó de recibir soporte en enero de 2020.",
    "El gestor de paquetes oficial de Python es pip, y los entornos virtuales se crean con venv o conda. PyPI es el repositorio oficial de paquetes.",
    "Python se utiliza ampliamente en inteligencia artificial, machine learning, automatización, desarrollo web, ciencia de datos y scripting."
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import Chroma
from langchain_classic.chains import RetrievalQA
from langchain_core.documents import Document
from google.colab import userdata
import google.generativeai as genai

genai.configure(api_key=userdata.get("GEMINI_API_KEY"))

# Listing available models to find a suitable embedding model
# You will need to uncomment and run this section to find a valid model if 'models/embedding-001' continues to fail
print("Available models:")
for m in genai.list_models():
    if 'embedContent' in m.supported_generation_methods:
        print(m.name)

# 1. Crea embeddings
# Replace 'models/embedding-001' with a valid model name from the list above that supports 'embedContent'
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-2-preview", google_api_key=userdata.get("GEMINI_API_KEY"))

# 2. Crea base vectorial con Chroma
db = Chroma.from_documents([
    Document(page_content=doc, metadata={'source': 'corpus'})
    for doc in corpus
], embeddings)

retriever = db.as_retriever()

# 3. Configura el LLM (Gemini)
llm = ChatGoogleGenerativeAI(model="gemini-pro-latest", google_api_key=userdata.get("GEMINI_API_KEY"), temperature=0.0)

# 4. Crea cadena RAG
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# Available models:
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2

# %%
try:
    from langchain_classic.chains import RetrievalQA
    print("✅ langchain.chains.RetrievalQA importado correctamente.")
except ModuleNotFoundError:
    print("❌ Error: langchain.chains.RetrievalQA no se pudo importar. Asegúrate de que las librerías estén instaladas y el entorno de ejecución reiniciado.")
# Out:
# ✅ langchain.chains.RetrievalQA importado correctamente.

# %% [markdown]
# ### C.1 — Pregunta: ¿Quién creó Python? (10 pts)

# %%
# C.1 — Responde usando tu RAG
respuesta_creador = qa_chain.invoke("¿Quién creó Python?")['result']  # El resultado de tu qa_chain

print(f"Respuesta: {respuesta_creador}")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070         try:
# -> 3071             response: GenerateContentResponse = self.client.models.generate_content(
#    3072                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
#    4527         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1235         retry = tenacity.Retrying(**retry_kwargs)
# -> 1236         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro\nPlease retry in 51.69412047s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'model': 'gemini-3.1-pro', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_cont...
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# /tmp/ipykernel_70561/3974899583.py in <cell line: 0>()
#       1 # C.1 — Responde usando tu RAG
# ----> 2 respuesta_creador = qa_chain.invoke("¿Quién creó Python?")['result']  # El resultado de tu qa_chain
#       3
#       4 print(f"Respuesta: {respuesta_creador}")
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154         answer = self.combine_documents_chain.run(
#     155             input_documents=docs,
#     156             question=question,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     635
#     636         if kwargs and not args:
# --> 637             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     638                 _output_key
#     639             ]
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     139         # Other keys are assumed to be needed for LLM prediction
#     140         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 141         output, extra_return_dict = self.combine_docs(
#     142             docs,
#     143             callbacks=_run_manager.get_child(),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     264         inputs = self._get_inputs(docs, **kwargs)
#     265         # Call predict on the LLM.
# --> 266         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     267
#     268     async def acombine_docs(
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in predict(self, callbacks, **kwargs)
#     313             ```
#     314         """
# --> 315         return self(kwargs, callbacks=callbacks)[self.output_key]
#     316
#     317     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in _call(self, inputs, run_manager)
#     115         run_manager: CallbackManagerForChainRun | None = None,
#     116     ) -> dict[str, str]:
# --> 117         response = self.generate([inputs], run_manager=run_manager)
#     118         return self.create_outputs(response)[0]
#     119
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in generate(self, input_list, run_manager)
#     127         callbacks = run_manager.get_child() if run_manager else None
#     128         if isinstance(self.llm, BaseLanguageModel):
# --> 129             return self.llm.generate_prompt(
#     130                 prompts,
#     131                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1750     ) -> LLMResult:
#    1751         prompt_messages = [p.to_messages() for p in prompts]
# -> 1752         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1753
#    1754     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1557             try:
#    1558                 results.append(
# -> 1559                     self._generate_with_cache(
#    1560                         m,
#    1561                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1897             result = generate_from_stream(iter(chunks))
#    1898         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1899             result = self._generate(
#    1900                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1901             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3073             )
#    3074         except ClientError as e:
# -> 3075             _handle_client_error(e, request)
#    3076
#    3077         return _response_to_result(response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _handle_client_error(e, request)
#     164     model_name = request.get("model", "unknown")
#     165     msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166     raise ChatGoogleGenerativeAIError(msg) from e
#     167
#     168
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-pro-latest' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro\nPlease retry in 51.69412047s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'model': 'gemini-3.1-pro', 'location'...

# %%
# Validación C.1 — NO MODIFICAR
assert respuesta_creador is not None, "Error: respuesta vacía"
assert "guido" in respuesta_creador.lower(), f"Error: la respuesta debe mencionar a Guido van Rossum"
print("✅ C.1 — Creador de Python: CORRECTO")

# %% [markdown]
# ### C.2 — Pregunta: ¿Cuáles son los frameworks de deep learning? (10 pts)

# %%
# C.2 — Pregunta sobre frameworks de deep learning
respuesta_frameworks = qa_chain.invoke("¿Cuáles son los frameworks de deep learning?")['result']  # El resultado de tu qa_chain

print(f"Respuesta: {respuesta_frameworks}")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070         try:
# -> 3071             response: GenerateContentResponse = self.client.models.generate_content(
#    3072                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
#    4527         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1235         retry = tenacity.Retrying(**retry_kwargs)
# -> 1236         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     392         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393             self._add_action_func(lambda rs: rs.outcome.result())
#     394             return
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# /tmp/ipykernel_70561/1235074205.py in <cell line: 0>()
#       1 # C.2 — Pregunta sobre frameworks de deep learning
# ----> 2 respuesta_frameworks = qa_chain.invoke("¿Cuáles son los frameworks de deep learning?")['result']  # El resultado de tu qa_chain
#       3
#       4 print(f"Respuesta: {respuesta_frameworks}")
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154         answer = self.combine_documents_chain.run(
#     155             input_documents=docs,
#     156             question=question,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     635
#     636         if kwargs and not args:
# --> 637             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     638                 _output_key
#     639             ]
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     139         # Other keys are assumed to be needed for LLM prediction
#     140         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 141         output, extra_return_dict = self.combine_docs(
#     142             docs,
#     143             callbacks=_run_manager.get_child(),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     264         inputs = self._get_inputs(docs, **kwargs)
#     265         # Call predict on the LLM.
# --> 266         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     267
#     268     async def acombine_docs(
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in predict(self, callbacks, **kwargs)
#     313             ```
#     314         """
# --> 315         return self(kwargs, callbacks=callbacks)[self.output_key]
#     316
#     317     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in _call(self, inputs, run_manager)
#     115         run_manager: CallbackManagerForChainRun | None = None,
#     116     ) -> dict[str, str]:
# --> 117         response = self.generate([inputs], run_manager=run_manager)
#     118         return self.create_outputs(response)[0]
#     119
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in generate(self, input_list, run_manager)
#     127         callbacks = run_manager.get_child() if run_manager else None
#     128         if isinstance(self.llm, BaseLanguageModel):
# --> 129             return self.llm.generate_prompt(
#     130                 prompts,
#     131                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1750     ) -> LLMResult:
#    1751         prompt_messages = [p.to_messages() for p in prompts]
# -> 1752         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1753
#    1754     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1557             try:
#    1558                 results.append(
# -> 1559                     self._generate_with_cache(
#    1560                         m,
#    1561                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1897             result = generate_from_stream(iter(chunks))
#    1898         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1899             result = self._generate(
#    1900                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1901             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3073             )
#    3074         except ClientError as e:
# -> 3075             _handle_client_error(e, request)
#    3076
#    3077         return _response_to_result(response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _handle_client_error(e, request)
#     164     model_name = request.get("model", "unknown")
#     165     msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166     raise ChatGoogleGenerativeAIError(msg) from e
#     167
#     168
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-pro' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
# Validación C.2 — NO MODIFICAR
assert respuesta_frameworks is not None, "Error: respuesta vacía"
resp_lower = respuesta_frameworks.lower()
assert "tensorflow" in resp_lower or "pytorch" in resp_lower, \
    "Error: la respuesta debe mencionar TensorFlow o PyTorch"
print("✅ C.2 — Frameworks DL: CORRECTO")

# %% [markdown]
# ### C.3 — Pregunta: ¿Para qué se usa Python? (15 pts)

# %%
# C.3 — Pregunta sobre usos de Python
respuesta_usos = qa_chain.invoke("¿Para qué se usa Python?")['result']  # El resultado de tu qa_chain

print(f"Respuesta: {respuesta_usos}")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070         try:
# -> 3071             response: GenerateContentResponse = self.client.models.generate_content(
#    3072                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
#    4527         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1235         retry = tenacity.Retrying(**retry_kwargs)
# -> 1236         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     392         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393             self._add_action_func(lambda rs: rs.outcome.result())
#     394             return
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# /tmp/ipykernel_70561/1831503954.py in <cell line: 0>()
#       1 # C.3 — Pregunta sobre usos de Python
# ----> 2 respuesta_usos = qa_chain.invoke("¿Para qué se usa Python?")['result']  # El resultado de tu qa_chain
#       3
#       4 print(f"Respuesta: {respuesta_usos}")
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154         answer = self.combine_documents_chain.run(
#     155             input_documents=docs,
#     156             question=question,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     635
#     636         if kwargs and not args:
# --> 637             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     638                 _output_key
#     639             ]
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     139         # Other keys are assumed to be needed for LLM prediction
#     140         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 141         output, extra_return_dict = self.combine_docs(
#     142             docs,
#     143             callbacks=_run_manager.get_child(),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     264         inputs = self._get_inputs(docs, **kwargs)
#     265         # Call predict on the LLM.
# --> 266         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     267
#     268     async def acombine_docs(
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in predict(self, callbacks, **kwargs)
#     313             ```
#     314         """
# --> 315         return self(kwargs, callbacks=callbacks)[self.output_key]
#     316
#     317     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     202                 warned = True
#     203                 emit_warning()
# --> 204             return wrapped(*args, **kwargs)
#     205
#     206         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     411         }
#     412
# --> 413         return self.invoke(
#     414             inputs,
#     415             cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in invoke(self, input, config, **kwargs)
#     165             self._validate_inputs(inputs)
#     166             outputs = (
# --> 167                 self._call(inputs, run_manager=run_manager)
#     168                 if new_arg_supported
#     169                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in _call(self, inputs, run_manager)
#     115         run_manager: CallbackManagerForChainRun | None = None,
#     116     ) -> dict[str, str]:
# --> 117         response = self.generate([inputs], run_manager=run_manager)
#     118         return self.create_outputs(response)[0]
#     119
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/llm.py in generate(self, input_list, run_manager)
#     127         callbacks = run_manager.get_child() if run_manager else None
#     128         if isinstance(self.llm, BaseLanguageModel):
# --> 129             return self.llm.generate_prompt(
#     130                 prompts,
#     131                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1750     ) -> LLMResult:
#    1751         prompt_messages = [p.to_messages() for p in prompts]
# -> 1752         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1753
#    1754     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1557             try:
#    1558                 results.append(
# -> 1559                     self._generate_with_cache(
#    1560                         m,
#    1561                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1897             result = generate_from_stream(iter(chunks))
#    1898         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1899             result = self._generate(
#    1900                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1901             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3073             )
#    3074         except ClientError as e:
# -> 3075             _handle_client_error(e, request)
#    3076
#    3077         return _response_to_result(response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _handle_client_error(e, request)
#     164     model_name = request.get("model", "unknown")
#     165     msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166     raise ChatGoogleGenerativeAIError(msg) from e
#     167
#     168
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-pro' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
print("Available chat models:")
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# Available chat models:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
print("Available chat models:")
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# Available chat models:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
# Validación C.3 — NO MODIFICAR
assert respuesta_usos is not None, "Error: respuesta vacía"
resp_lower = respuesta_usos.lower()
usos_mencionados = sum(1 for uso in ["inteligencia artificial", "machine learning", "web", "datos", "automatización"]
                       if uso in resp_lower or uso.split()[0] in resp_lower)
assert usos_mencionados >= 2, f"Error: la respuesta debe mencionar al menos 2 usos de Python"
print("✅ C.3 — Usos de Python: CORRECTO")

# %% [markdown]
# ---
# ## 📋 Autoevaluación — Responde en Blackboard
#
# Una vez hayas completado las actividades, ve a **Blackboard** y responde el formulario con las siguientes preguntas.
#
# ---
#
# ### Pregunta 1 (Verdadero / Falso)
#
# **La función `pipeline()` de HuggingFace permite usar modelos pre-entrenados con muy pocas líneas de código, sin necesidad de entrenar nada.**
#
# ---
#
# ### Pregunta 2 (Multirespuesta)
#
# **¿Qué tipo de pipeline se usa para clasificar texto en categorías sin haberlo entrenado específicamente para esas categorías?**
#
# - a) `sentiment-analysis`
# - b) `text-generation`
# - c) `zero-shot-classification`
# - d) `question-answering`
#
# ---
#
# ### Pregunta 3 (Verdadero / Falso)
#
# **De las 10 reseñas del ejercicio (Parte A.1), hay exactamente 6 positivas y 4 negativas según el pipeline de sentiment-analysis.**
#
# ---
#
# ### Pregunta 4 (Multirespuesta)
#
# **En un sistema RAG, ¿cuál es la función del paso de "retrieval" (recuperación)?**
#
# - a) Generar la respuesta final con el LLM
# - b) Entrenar el modelo con los documentos
# - c) Buscar los documentos más relevantes de la base de conocimiento
# - d) Tokenizar el texto de entrada
#
# ---
#
# ### Pregunta 5 (Verdadero / Falso)
#
# **La API de chat de Gemini mantiene el contexto de la conversación a lo largo de múltiples mensajes (chat multi-turno).**
#
# ---
#
# ### Pregunta 6 (Multirespuesta)
#
# **En un sistema RAG, ¿qué componente almacena los embeddings vectoriales para la búsqueda por similitud?**
#
# - a) El LLM (Large Language Model)
# - b) El tokenizer
# - c) La base de datos vectorial (ej: Chroma)
# - d) El prompt template
#
# ---
#
# ### Pregunta 7 (Verdadero / Falso)
#
# **Zero-shot classification requiere hacer fine-tuning del modelo con nuestras categorías específicas antes de poder usarlo.**
#
# ---
#
# ### Pregunta 8 (Multirespuesta)
#
# **Si hacemos 3 preguntas en un chat multi-turno con Gemini (Parte B.2), ¿cuántos mensajes tiene el historial del chat?**
#
# - a) 3
# - b) 4
# - c) 6
# - d) 9
